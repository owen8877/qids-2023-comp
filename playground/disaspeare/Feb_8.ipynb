# %%
import pandas as pd
from matplotlib import pyplot as plt
from pandas import Series
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit

from pipeline import Dataset

from pandas.plotting import lag_plot, autocorrelation_plot
import seaborn as sns

# %%
dataset = Dataset.load()

# %%
m_agg_df = dataset.market.groupby(by=['asset', 'day']).mean().reset_index()
full_df = pd.concat([m_agg_df.set_index(['asset', 'day'])[['close']], dataset.fundamental.set_index(['asset', 'day']),
                     dataset.ref_return.set_index(['asset', 'day'])], axis=1).dropna()  # dropna just for training

# %%
autocorrelation_plot(full_df.loc[full_df.index.get_level_values(0) == 2]['return'])
plt.gca().set(xlim=[0, 10])
# Out:
# [(0.0, 10.0)]

# %%
def get_single_day_return(s):
    return (s.shift(-1) / s - 1).fillna(0)

# %%
rr = get_single_day_return(
    dataset.market.set_index('asset').loc[0].set_index('timeslot').loc[50].set_index('day')['close'])

# %%
rr
# Out:
# day
# 1      -0.032352
# 2       0.005658
# 3       0.023017
# 4       0.083000
# 5      -0.012928
#           ...
# 996     0.015952
# 997    -0.011772
# 998    -0.011920
# 999    -0.007038
# 1000    0.000000
# Name: close, Length: 1000, dtype: float64

# %%
wdf = dataset.market.groupby(by='asset').apply(
    lambda df: get_single_day_return(df.set_index('timeslot').loc[50].set_index('day')['close']))

# %%
wdf
# Out:
# day        1         2         3         4         5         6         7     \
# asset
# 0     -0.032352  0.005658  0.023017  0.083000 -0.012928 -0.014497 -0.010444
# 1     -0.060949  0.008813  0.064338  0.040302  0.007890  0.002844 -0.022710
# 2     -0.037638  0.036314 -0.005396  0.048784 -0.015498 -0.013125  0.011963
# 3     -0.029097  0.010899  0.057948  0.010191 -0.013870 -0.012790  0.003895
# 4     -0.026376  0.007386  0.004895  0.048670 -0.011603 -0.014079 -0.019047
# 5      0.014971  0.009320 -0.023848  0.047283  0.019564  0.000736 -0.017698
# 6      0.024999 -0.006104  0.009199 -0.024315 -0.006237 -0.043879 -0.006564
# 7      0.006387  0.007938  0.032020  0.025432 -0.015378  0.003026 -0.014565
# 8     -0.015514  0.003645  0.032606  0.017547 -0.017244  0.003507 -0.020981
# 9     -0.029988  0.010277  0.045944  0.004863  0.014558 -0.033467  0.004935
# 10    -0.036706  0.012362  0.029501  0.037546  0.002856 -0.017095  0.021261
# 11     0.010807 -0.006234 -0.008076  0.023509 -0.005298 -0.003556  0.011587
# 12     0.039927 -0.019197  0.031310  0.001907 -0.013263 -0.021110 -0.009806
# 13    -0.017097  0.019128  0.014509  0.025228 -0.015585  0.019168 -0.022082
# 14     0.009297  0.021468 -0.003006  0.018078  0.001475 -0.005902 -0.004456
# 15    -0.044178  0.003261 -0.001085  0.030929 -0.005789  0.009530  0.007340
# 16    -0.015409  0.007830  0.043985  0.007432 -0.027057  0.005051  0.012581
# 17    -0.037341 -0.016852  0.015431  0.037157  0.000000  0.024434  0.007950
# 18     0.010074 -0.017668  0.061793 -0.020765 -0.034320  0.015604 -0.030158
# 19     0.026272 -0.007988 -0.012903 -0.006542 -0.014797  0.001664 -0.001661
# Out:
#    asset day  hold_1_return
# 0      0   1      -0.032352
# 1      0   2       0.005658
# 2      0   3       0.023017
# 3      0   4       0.083000
# 4      0   5      -0.012928

# %%
day_before_hold_1_return = hold_1_return.set_index(['asset', 'day']).groupby(level=0).shift(1, fill_value=0)

# %%
dataset.ref_return.sort_values(['asset', 'day'])
# Out:
#        asset  day    return
# 0          0    1 -0.026877
# 54         0    2  0.028805
# 108        0    3  0.107928
# 162        0    4  0.068998
# 216        0    5 -0.027238
# ...      ...  ...       ...
# 53675     53  994  0.020942
# 53729     53  995  0.042851
# 53783     53  996  0.050002
# 53837     53  997  0.019924
# 53891     53  998 -0.003662
#
# [53892 rows x 3 columns]

# %%
full_df['hold_1_return'] = hold_1_return.set_index(['asset', 'day'])

# %%
full_df['day_before_hold_1_return'] = day_before_hold_1_return

# %%
sns.pairplot(full_df[['return', 'day_before_hold_1_return']], kind='kde')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 sns.pairplot(full_df[['return', 'day_before_hold_1_return']], kind='kde')
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/axisgrid.py:2165, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2163     from .distributions import kdeplot  # Avoid circular import
#    2164     plot_kws.setdefault("warn_singular", False)
# -> 2165     plotter(kdeplot, **plot_kws)
#    2166 elif kind == "hist":
#    2167     from .distributions import histplot  # Avoid circular import
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/axisgrid.py:1421, in PairGrid.map_offdiag(self, func, **kwargs)
#    1419     self.map_lower(func, **kwargs)
#    1420     if not self._corner:
# -> 1421         self.map_upper(func, **kwargs)
#    1422 else:
#    1423     indices = []
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/axisgrid.py:1404, in PairGrid.map_upper(self, func, **kwargs)
#    1393 """Plot with a bivariate function on the upper diagonal subplots.
#    1394
#    1395 Parameters
#    (...)
#    1401
#    1402 """
#    1403 indices = zip(*np.triu_indices_from(self.axes, 1))
# -> 1404 self._map_bivariate(func, indices, **kwargs)
#    1405 return self
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/axisgrid.py:1568, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1566     if ax is None:  # i.e. we are in corner mode
#    1567         continue
# -> 1568     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1569 self._add_axis_labels()
#    1571 if "hue" in signature(func).parameters:
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/axisgrid.py:1609, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1605 if "hue" not in kwargs:
#    1606     kwargs.update({
#    1607         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1608     })
# -> 1609 func(x=x, y=y, **kwargs)
#    1611 self._update_legend_data(ax)
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/distributions.py:1731, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    (...)
#    1726         **plot_kws,
#    1727     )
#    1729 else:
# -> 1731     p.plot_bivariate_density(
#    1732         common_norm=common_norm,
#    1733         fill=fill,
#    1734         levels=levels,
#    1735         thresh=thresh,
#    1736         legend=legend,
#    1737         color=color,
#    1738         warn_singular=warn_singular,
#    1739         cbar=cbar,
#    1740         cbar_ax=cbar_ax,
#    1741         cbar_kws=cbar_kws,
#    1742         estimate_kws=estimate_kws,
#    1743         **kwargs,
#    1744     )
#    1746 return ax
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/distributions.py:1081, in _DistributionPlotter.plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1079 try:
#    1080     if not singular:
# -> 1081         density, support = estimator(*observations, weights=weights)
#    1082 except np.linalg.LinAlgError:
#    1083     # Testing for 0 variance doesn't catch all cases where scipy raises,
#    1084     # but we can also get a ValueError, so we need this convoluted approach
#    1085     singular = True
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/_statistics.py:194, in KDE.__call__(self, x1, x2, weights)
#     192     return self._eval_univariate(x1, weights)
#     193 else:
# --> 194     return self._eval_bivariate(x1, x2, weights)
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/seaborn/_statistics.py:185, in KDE._eval_bivariate(self, x1, x2, weights)
#     182 else:
#     184     xx1, xx2 = np.meshgrid(*support)
# --> 185     density = kde([xx1.ravel(), xx2.ravel()]).reshape(xx1.shape)
#     187 return density, support
#
# File /opt/miniconda3/envs/qids-2023-comp/lib/python3.10/site-packages/scipy/stats/_kde.py:268, in gaussian_kde.evaluate(self, points)
#     265         raise ValueError(msg)
#     267 output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 268 result = gaussian_kernel_estimate[spec](
#     269     self.dataset.T, self.weights[:, None],
#     270     points.T, self.cho_cov, output_dtype)
#     272 return result[:, 0]
#
# KeyboardInterrupt:

# %%
full_df.reset_index().groupby('asset')
# Out:
#        asset  day      close  turnoverRatio  transactionAmount   pe_ttm  \
# 0          0    1  24.536720         3.6794            17229.0  34.4425
# 1          0    2  23.938318         3.2535            18378.0  33.3198
# 2          0    3  23.628554         2.4947            13686.0  23.3887
# 3          0    4  23.847280         4.5625            22587.0  23.9187
# 4          0    5  26.002992        18.2257            65239.0  25.9119
# ...      ...  ...        ...            ...                ...      ...
# 53887     53  994   9.334846         0.6555             5554.0   9.9428
# 53888     53  995   9.349170         0.6154             6417.0  10.0148
# 53889     53  996   9.440208         0.8417             5204.0  10.1469
# 53890     53  997   9.816240         1.4411             9143.0  10.4471
# 53891     53  998   9.827900         1.2933             9681.0  10.6513
#
#             pe      pb      ps       pcf    return  hold_1_return  \
# 0      32.3029  4.9425  3.8180 -578.7700 -0.026877      -0.032352
# 1      31.2498  4.7814  3.6935 -559.9031  0.028805       0.005658
# 2      23.3887  4.3823  2.9722  -42.8676  0.107928       0.023017
# 3      23.9187  4.4816  3.0396  -43.8390  0.068998       0.083000
# 4      25.9119  4.8551  3.2929  -47.4923 -0.027238      -0.012928
# ...        ...     ...     ...       ...       ...            ...
# 53887   9.9428  1.8629  0.3802  125.5971  0.020942       0.007861
# 53888  10.0148  1.8764  0.3830  126.5072  0.042851       0.012978
# 53889  10.1469  1.9012  0.3880  128.1758  0.050002       0.029490
# 53890  10.4471  1.9574  0.3995  131.9680  0.019924       0.019924
# 53891  10.6513  1.9956  0.4073  134.5467 -0.003662       0.000000
#
#        day_before_hold_1_return
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 53887                       NaN
# 53888                       NaN
# 53889                       NaN
# 53890                       NaN
# 53891                       NaN
#
# [53892 rows x 13 columns]

# %%
full_df.swaplevel().sort_index()
# Out:
#                close  turnoverRatio  transactionAmount    pe_ttm        pe  \
# day asset
# 1   0      24.536720         3.6794            17229.0   34.4425   32.3029
#     1      16.159082         2.5150             3706.0   28.9934   27.2726
#     2       9.051792         1.2858             5136.0   42.9352   41.9279
#     3       9.113946         2.2007             3280.0   15.2245   13.8032
#     4       5.053044         0.8627             5291.0 -369.9850 -433.1736
# ...              ...            ...                ...       ...       ...
# 998 49     13.931758         0.3720             5676.0   41.1121   41.1121
#     50     11.208480         0.4780             4506.0   19.4678   19.4678
#     51      3.749418         1.1501             5179.0   14.5922   14.5922
#     52     28.825080         0.5684             7558.0   28.9922   28.9922
#     53      9.827900         1.2933             9681.0   10.6513   10.6513
#
#                pb      ps       pcf    return  hold_1_return  \
# day asset
# 1   0      4.9425  3.8180 -578.7700 -0.026877      -0.032352
#     1      5.0552  3.0484   23.8260 -0.052674      -0.060949
#     2      4.8083  4.1392  -58.2185 -0.002691      -0.037638
#     3      2.1904  0.6691   61.0491 -0.018515      -0.029097
#     4      3.0714  2.9370  -25.2279 -0.019184      -0.026376
# ...           ...     ...       ...       ...            ...
# 998 49     2.8312  1.0491   73.1850 -0.014799      -0.006962
#     50     2.5076  1.1590  -38.0915  0.012921       0.004310
#     51     1.4130  0.7009   19.5205 -0.052286      -0.026143
#     52     5.7855  3.7150 -582.4621 -0.015559      -0.019765
#     53     1.9956  0.4073  134.5467 -0.003662       0.000000
#
#            day_before_hold_1_return
# day asset
# 1   0                      0.000000
#     1                      0.000000
#     2                      0.000000
#     3                      0.000000
#     4                      0.000000
# ...                             ...
# 998 49                    -0.014577
#     50                    -0.013801
#     51                    -0.040754
#     52                     0.004224
#     53                     0.019924
#
# [53892 rows x 11 columns]

# %%
dataset.market.set_index('asset').loc[0].set_index('day').loc[1]
# Out:
# 1          39  24.5188  24.5188  24.5430  24.4823   383726.0  9.403556e+06
# 1          40  24.5066  24.4945  24.5188  24.4702   498034.0  1.219261e+07
# 1          41  24.4702  24.4823  24.5066  24.4581   276270.0  6.764374e+06
# 1          42  24.4823  24.4702  24.5066  24.4702   278243.0  6.813380e+06
# 1          43  24.4823  24.3731  24.4823  24.3731  1052860.0  2.571223e+07
# 1          44  24.3731  24.3731  24.3852  24.3124   636533.0  1.549720e+07
# 1          45  24.3731  24.3974  24.4338  24.3731   434391.0  1.060111e+07
# 1          46  24.3974  24.3731  24.4095  24.3367   535305.0  1.304476e+07
# 1          47  24.3852  24.2517  24.3852  24.2517   979769.0  2.381767e+07
# 1          48  24.2396  24.3974  24.4217  24.2396   562092.0  1.368504e+07
# 1          49  24.4095  24.3731  24.4095  24.3610   481838.0  1.175247e+07
# 1          50  24.3731  24.3852  24.3852  24.3731   170476.0  4.157520e+06

# %%
def extract_intraday(df):
    df = df.set_index('timeslot')

    return Series({
        'open': df.loc[1]['open'],
        'close_price': df.loc[50]['close'],
        'high_price': df['high'].max(),
        'low_price': df['low'].min(),
        'std': df['close'].std(),
        'mean': df['close'].mean(),
        'volume': df['volume'].sum(),
        'money': df['money'].sum(),
    })

# %%
sub = dataset.market.set_index('day').loc[:5].reset_index()
sub.groupby(['asset', 'day']).apply(extract_intraday)
# sub
# Out:
#               open  close_price  high_price  low_price       std       mean  \
# asset day
# 0     1    25.0164      24.3852     25.1378    24.2396  0.121904  24.536720
#       2    24.4217      23.5963     24.5552    23.5234  0.317253  23.938318
#       3    23.5963      23.7298     23.7783    23.3899  0.073839  23.628554
#       4    23.6812      24.2760     24.3610    23.3778  0.335550  23.847280
#       5    24.3003      26.2909     26.7036    23.9847  0.634391  26.002992
# ...            ...          ...         ...        ...       ...        ...
# 53    1     8.8850       8.8001      8.9093     8.7515  0.029580   8.812922
#       2     8.7636       8.5209      8.8122     8.4602  0.077172   8.639582
#       3     8.5087       8.6058      8.6544     8.5087  0.035475   8.587400
#       4     8.6180       8.9336      8.9700     8.5816  0.084805   8.861716
#       5     8.8729       9.0792      9.1035     8.7636  0.052553   9.006628
#
#                 volume         money
# asset day
# 0     1     22703792.0  5.574624e+08
#       2     20075851.0  4.800800e+08
#       3     15398462.0  3.637981e+08
#       4     28162025.0  6.723506e+08
#       5    112498597.0  2.939903e+09
# ...                ...           ...
# 53    1      6696751.0  5.896871e+07
#       2      9305418.0  8.021630e+07
#       3      4242748.0  3.644933e+07
#       4     12603841.0  1.118195e+08
#       5     14320435.0  1.290759e+08
#
# [270 rows x 8 columns]

# %%
import numpy as np

m_agg_df = pd.concat([
    sub.set_index('timeslot').loc[1].set_index(['asset', 'day'])['open'],
    sub.set_index('timeslot').loc[50].set_index(['asset', 'day'])['close'],
    sub.groupby(['asset', 'day']).agg(high=('high', max), low=('low', min), var=('close', np.std), avg=('close', np.mean), volume=('volume', np.sum), money=('money', np.sum)),
], axis=1)
